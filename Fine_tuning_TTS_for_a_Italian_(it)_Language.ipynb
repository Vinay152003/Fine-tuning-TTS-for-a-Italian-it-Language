# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.4 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers

# %%
# !pip install transformers datasets soundfile

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.4/447.4 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 37.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 351.7 kB/s eta 0:00:00
# ...

# %%
from google.colab import auth

# Authenticate with Hugging Face Hub
auth.authenticate_user()

# %%
import os

# Set your Hugging Face token
os.environ["HF_TOKEN"] = "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"

# %%
# !pip install tokenizer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.8/112.8 kB 9.1 MB/s eta 0:00:00
# ...

# %%
# !pip install phonemizer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.4/213.4 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.1/562.1 kB 34.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.2/116.2 kB 9.9 MB/s eta 0:00:00
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=da950df7ea8a7da580fcf7d0008e4a95bc6f5b6a51afc34a1bd1762df840e00a
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# ...

# %%
import gradio as gr
import torch
from datasets import load_dataset
from transformers import SpeechT5Processor, SpeechT5HifiGan, SpeechT5ForTextToSpeech

# Load the fine-tuned model and vocoder for Italian from the new model ID
model_id = "Vinay15/speecht5_finetuned_voxpopuli_it"
model = SpeechT5ForTextToSpeech.from_pretrained(model_id)
vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")

# Load speaker embeddings dataset
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")
speaker_embeddings = torch.tensor(embeddings_dataset[7440]["xvector"]).unsqueeze(0)

# Load processor for the new Italian model
processor = SpeechT5Processor.from_pretrained(model_id)

# Optional: Text cleanup for Italian-specific characters
replacements = [
    ("à", "a"),
    ("è", "e"),
    ("é", "e"),
    ("ì", "i"),
    ("ò", "o"),
    ("ù", "u"),
]

# Text-to-speech synthesis function
def synthesize_speech(text):
    # Clean up text for Italian-specific accents
    for src, dst in replacements:
        text = text.replace(src, dst)

    # Process input text
    inputs = processor(text=text, return_tensors="pt")

    # Generate speech using the model and vocoder
    speech = model.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)

    # Return the generated speech as (sample_rate, audio_array)
    return (16000, speech.cpu().numpy())

# Title and description for the Gradio interface
title = "Italian Text-to-Speech with SpeechT5"
description = """
This demo generates speech in Italian using the fine-tuned SpeechT5 model from Hugging Face.
The model is fine-tuned on the VoxPopuli Italian dataset.
"""

# Create Gradio interface
interface = gr.Interface(
    fn=synthesize_speech,
    inputs=gr.Textbox(label="Input Text", placeholder="Enter Italian text here..."),
    outputs=gr.Audio(label="Generated Speech"),
    title=title,
    description=description,
    examples=["Questa è una dimostrazione di sintesi vocale in italiano."]
)

# Launch the interface
interface.launch()
# Out:
# config.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/585M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/458 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# spm_char.model:   0%|          | 0.00/238k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ec38930e1c07524b1e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...

# %%
import time
import numpy as np

# Text-to-speech synthesis function with time measurement
def synthesize_speech_with_time(text):
    # Clean up text for Italian characters
    for src, dst in replacements:
        text = text.replace(src, dst)

    # Process input text
    inputs = processor(text=text, return_tensors="pt")

    # Start measuring inference time
    start_time = time.time()

    # Generate speech using the model and vocoder
    speech = model.generate_speech(inputs["input_ids"], speaker_embeddings, vocoder=vocoder)

    # End measuring inference time
    inference_time = time.time() - start_time

    # Return the generated speech and inference time
    return (16000, speech.cpu().numpy(), inference_time)

# Example usage
text = "Questa è una dimostrazione di sintesi vocale in italiano."
sample_rate, speech, inference_time = synthesize_speech_with_time(text)

print(f"Inference Time: {inference_time:.2f} seconds")
# Out:
# Inference Time: 12.23 seconds

# %%
# List to store MOS scores from evaluators
mos_scores = []

def collect_mos_score(score):
    # Append the given score to the list
    mos_scores.append(score)
    print(f"Received score: {score}")

# Function to play audio and collect the MOS score
def evaluate_mos(text):
    # Synthesize speech
    sample_rate, speech, _ = synthesize_speech_with_time(text)

    # Play the generated audio for human evaluation
    print(f"Playing audio: {text}")
    # In a real-world scenario, you would use an interface like Gradio to play the audio

    # Collect a score (1 to 5) from a human evaluator
    score = int(input("Rate the audio quality (1: Bad, 5: Excellent): "))

    # Record the MOS score
    collect_mos_score(score)

    return sample_rate, speech

# Example usage to synthesize and evaluate MOS for a sentence
evaluate_mos("Questa è una dimostrazione di sintesi vocale in italiano.")

# Print all collected MOS scores
print(f"Collected MOS Scores: {mos_scores}")
print(f"Average MOS Score: {np.mean(mos_scores)}")
# Out:
# Playing audio: Questa è una dimostrazione di sintesi vocale in italiano.
# Rate the audio quality (1: Bad, 5: Excellent): 5
# Received score: 5
# Collected MOS Scores: [5]
# Average MOS Score: 5.0
